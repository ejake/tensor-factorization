# %% [markdown]
# ## imports

# %%
import numpy
import theano
from theano import tensor
from fuel.streams import DataStream
from fuel.schemes import ShuffledScheme
from fuel.datasets.iris import Iris
from fuel.transformers import Mapping
from blocks.bricks import Linear, Softmax, Logistic
from blocks.bricks.cost import MisclassificationRate
from blocks.initialization import Uniform, Constant
from blocks.graph import ComputationGraph
from blocks.algorithms import GradientDescent, Scale
from blocks.main_loop import MainLoop
from blocks.extensions import Timing, FinishAfter, Printing
from blocks.extensions.monitoring import TrainingDataMonitoring
from blocks.extras.extensions.plot import Plot
from sklearn import metrics
import os
os.environ['FUEL_DATA_PATH'] = '/home/datasets/datasets1/fuel/'

# %% [markdown]
# ## Params

# %%
learning_rate = 0.01
nclasses = 3
nfeatures = 4
nhiddens = 5
batch_size = 32
nepochs = 300

# %% [markdown]
# # Data

# %%
dataset = Iris(which_sets=('all',))
scheme = ShuffledScheme(examples=dataset.num_examples, batch_size=batch_size)
stream = DataStream(dataset, iteration_scheme=scheme)

# %% [markdown]
# ## One-hot representation

# %%
I = numpy.eye(nclasses, dtype=int)
def one_hot(data):
    return data[0], I[data[1].flatten()]
stream = Mapping(stream, one_hot)

# %% [markdown]
# # Model

# %%
x = tensor.matrix('features')
y = tensor.lmatrix('targets')
linear = Linear(nfeatures, nclasses,
                weights_init=Constant(0), biases_init=Constant(0))
linear.initialize()
linear_output = linear.apply(x)
softmax = Softmax()
y_hat = softmax.apply(linear_output)

# %% [markdown]
# ## cost

# %%
cost = softmax.categorical_cross_entropy(y, linear_output).mean()
error = MisclassificationRate().apply(y.nonzero()[1], y_hat)
error.name = 'error'
cost.name = 'cost'

# %% [markdown]
# # Algorithm

# %%
cg = ComputationGraph(cost)
algorithm = GradientDescent(cost=cost, parameters=cg.parameters,
                            step_rule=Scale(learning_rate))

# %% [markdown]
# # Extensions

# %%
monitor = TrainingDataMonitoring([cost, error], prefix='tra', after_batch=True)
extensions=[monitor, Printing(), Timing(), FinishAfter(after_n_epochs=nepochs)]

# %% [markdown]
# # Main loop

# %%
loop = MainLoop(algorithm, stream, extensions=extensions)
loop.run()
# Out:
# -------------------------------------------------------------------------------
# BEFORE FIRST EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: True
# 	 epochs_done: 0
# 	 iterations_done: 0
# 	 received_first_batch: False
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 0:
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 1
# 	 iterations_done: 5
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 5:
# 	 tra_cost: 1.07524915068
# 	 tra_error: 0.727272727273
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 2
# 	 iterations_done: 10
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 10:
# 	 tra_cost: 1.03671718468
# 	 tra_error: 0.681818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 3
# 	 iterations_done: 15
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 15:
# 	 tra_cost: 1.04495450183
# 	 tra_error: 0.772727272727
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 4
# 	 iterations_done: 20
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 20:
# 	 tra_cost: 0.97395325064
# 	 tra_error: 0.363636363636
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 5
# 	 iterations_done: 25
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 25:
# 	 tra_cost: 0.921669753344
# 	 tra_error: 0.318181818182
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 6
# 	 iterations_done: 30
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 30:
# 	 tra_cost: 0.911413365442
# 	 tra_error: 0.318181818182
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 7
# 	 iterations_done: 35
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 35:
# 	 tra_cost: 0.954675053484
# 	 tra_error: 0.409090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 8
# 	 iterations_done: 40
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 40:
# 	 tra_cost: 0.924997240624
# 	 tra_error: 0.5
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 9
# 	 iterations_done: 45
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 45:
# 	 tra_cost: 0.871201610048
# 	 tra_error: 0.409090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 10
# 	 iterations_done: 50
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 50:
# 	 tra_cost: 0.833063561105
# 	 tra_error: 0.272727272727
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 11
# 	 iterations_done: 55
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 55:
# 	 tra_cost: 0.795978162768
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 12
# 	 iterations_done: 60
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 60:
# 	 tra_cost: 0.804255422255
# 	 tra_error: 0.318181818182
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 13
# 	 iterations_done: 65
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 65:
# 	 tra_cost: 0.871234490262
# 	 tra_error: 0.5
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 14
# 	 iterations_done: 70
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 70:
# 	 tra_cost: 0.750758578126
# 	 tra_error: 0.227272727273
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 15
# 	 iterations_done: 75
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 75:
# 	 tra_cost: 0.759715029761
# 	 tra_error: 0.272727272727
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 16
# 	 iterations_done: 80
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 80:
# 	 tra_cost: 0.761370542272
# 	 tra_error: 0.363636363636
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 17
# 	 iterations_done: 85
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 85:
# 	 tra_cost: 0.680759553992
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 18
# 	 iterations_done: 90
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 90:
# 	 tra_cost: 0.708750916322
# 	 tra_error: 0.318181818182
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 19
# 	 iterations_done: 95
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 95:
# 	 tra_cost: 0.74205028524
# 	 tra_error: 0.272727272727
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 20
# 	 iterations_done: 100
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 100:
# 	 tra_cost: 0.724778035879
# 	 tra_error: 0.409090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 21
# 	 iterations_done: 105
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 105:
# 	 tra_cost: 0.7906199199
# 	 tra_error: 0.5
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 22
# 	 iterations_done: 110
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 110:
# 	 tra_cost: 0.659192281516
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 23
# 	 iterations_done: 115
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 115:
# 	 tra_cost: 0.795457065204
# 	 tra_error: 0.545454545455
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 24
# 	 iterations_done: 120
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 120:
# 	 tra_cost: 0.615438034957
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 25
# 	 iterations_done: 125
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 125:
# 	 tra_cost: 0.656468024038
# 	 tra_error: 0.272727272727
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 26
# 	 iterations_done: 130
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 130:
# 	 tra_cost: 0.616276967294
# 	 tra_error: 0.227272727273
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 27
# 	 iterations_done: 135
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 135:
# 	 tra_cost: 0.688859609954
# 	 tra_error: 0.363636363636
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 28
# 	 iterations_done: 140
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 140:
# 	 tra_cost: 0.633371176506
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 29
# 	 iterations_done: 145
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 145:
# 	 tra_cost: 0.642081413047
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 30
# 	 iterations_done: 150
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 150:
# 	 tra_cost: 0.732475244781
# 	 tra_error: 0.5
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 31
# 	 iterations_done: 155
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 155:
# 	 tra_cost: 0.595364612156
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 32
# 	 iterations_done: 160
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 160:
# 	 tra_cost: 0.549366234879
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 33
# 	 iterations_done: 165
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 165:
# 	 tra_cost: 0.616641507666
# 	 tra_error: 0.272727272727
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 34
# 	 iterations_done: 170
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 170:
# 	 tra_cost: 0.62515793759
# 	 tra_error: 0.363636363636
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 35
# 	 iterations_done: 175
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 175:
# 	 tra_cost: 0.649914145687
# 	 tra_error: 0.454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 36
# 	 iterations_done: 180
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 180:
# 	 tra_cost: 0.672739442543
# 	 tra_error: 0.363636363636
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 37
# 	 iterations_done: 185
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 185:
# 	 tra_cost: 0.617097797695
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 38
# 	 iterations_done: 190
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 190:
# 	 tra_cost: 0.562733174039
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 39
# 	 iterations_done: 195
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 195:
# 	 tra_cost: 0.546260613979
# 	 tra_error: 0.272727272727
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 40
# 	 iterations_done: 200
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 200:
# 	 tra_cost: 0.585312681436
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 41
# 	 iterations_done: 205
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 205:
# 	 tra_cost: 0.546241313337
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 42
# 	 iterations_done: 210
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 210:
# 	 tra_cost: 0.543003586855
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 43
# 	 iterations_done: 215
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 215:
# 	 tra_cost: 0.6416777583
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 44
# 	 iterations_done: 220
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 220:
# 	 tra_cost: 0.568692937497
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 45
# 	 iterations_done: 225
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 225:
# 	 tra_cost: 0.574745065561
# 	 tra_error: 0.272727272727
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 46
# 	 iterations_done: 230
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 230:
# 	 tra_cost: 0.551881515995
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 47
# 	 iterations_done: 235
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 235:
# 	 tra_cost: 0.546395073264
# 	 tra_error: 0.227272727273
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 48
# 	 iterations_done: 240
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 240:
# 	 tra_cost: 0.494276388994
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 49
# 	 iterations_done: 245
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 245:
# 	 tra_cost: 0.498139711199
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 50
# 	 iterations_done: 250
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 250:
# 	 tra_cost: 0.525560952329
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 51
# 	 iterations_done: 255
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 255:
# 	 tra_cost: 0.542337345248
# 	 tra_error: 0.227272727273
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 52
# 	 iterations_done: 260
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 260:
# 	 tra_cost: 0.514900360392
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 53
# 	 iterations_done: 265
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 265:
# 	 tra_cost: 0.498247061808
# 	 tra_error: 0.272727272727
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 54
# 	 iterations_done: 270
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 270:
# 	 tra_cost: 0.527300141915
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 55
# 	 iterations_done: 275
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 275:
# 	 tra_cost: 0.477782152927
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 56
# 	 iterations_done: 280
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 280:
# 	 tra_cost: 0.549219357103
# 	 tra_error: 0.272727272727
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 57
# 	 iterations_done: 285
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 285:
# 	 tra_cost: 0.554813641671
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 58
# 	 iterations_done: 290
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 290:
# 	 tra_cost: 0.466350480099
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 59
# 	 iterations_done: 295
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 295:
# 	 tra_cost: 0.516363528871
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 60
# 	 iterations_done: 300
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 300:
# 	 tra_cost: 0.570029928871
# 	 tra_error: 0.318181818182
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 61
# 	 iterations_done: 305
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 305:
# 	 tra_cost: 0.632969227275
# 	 tra_error: 0.318181818182
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 62
# 	 iterations_done: 310
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 310:
# 	 tra_cost: 0.586631647614
# 	 tra_error: 0.227272727273
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 63
# 	 iterations_done: 315
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 315:
# 	 tra_cost: 0.482759607856
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 64
# 	 iterations_done: 320
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 320:
# 	 tra_cost: 0.551737179429
# 	 tra_error: 0.318181818182
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 65
# 	 iterations_done: 325
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 325:
# 	 tra_cost: 0.402959883254
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 66
# 	 iterations_done: 330
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 330:
# 	 tra_cost: 0.506498818773
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 67
# 	 iterations_done: 335
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 335:
# 	 tra_cost: 0.474603399198
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 68
# 	 iterations_done: 340
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 340:
# 	 tra_cost: 0.452557375039
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 69
# 	 iterations_done: 345
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 345:
# 	 tra_cost: 0.462071588174
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 70
# 	 iterations_done: 350
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 350:
# 	 tra_cost: 0.574472624553
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 71
# 	 iterations_done: 355
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 355:
# 	 tra_cost: 0.419600509605
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 72
# 	 iterations_done: 360
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 360:
# 	 tra_cost: 0.514852337042
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 73
# 	 iterations_done: 365
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 365:
# 	 tra_cost: 0.424782630297
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 74
# 	 iterations_done: 370
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 370:
# 	 tra_cost: 0.497186033849
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 75
# 	 iterations_done: 375
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 375:
# 	 tra_cost: 0.551021332682
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 76
# 	 iterations_done: 380
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 380:
# 	 tra_cost: 0.5116213167
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 77
# 	 iterations_done: 385
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 385:
# 	 tra_cost: 0.499052945275
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 78
# 	 iterations_done: 390
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 390:
# 	 tra_cost: 0.467933640575
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 79
# 	 iterations_done: 395
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 395:
# 	 tra_cost: 0.490918779156
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 80
# 	 iterations_done: 400
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 400:
# 	 tra_cost: 0.506046860777
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 81
# 	 iterations_done: 405
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 405:
# 	 tra_cost: 0.446738318125
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 82
# 	 iterations_done: 410
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 410:
# 	 tra_cost: 0.418939587848
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 83
# 	 iterations_done: 415
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 415:
# 	 tra_cost: 0.435207230914
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 84
# 	 iterations_done: 420
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 420:
# 	 tra_cost: 0.427446752301
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 85
# 	 iterations_done: 425
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 425:
# 	 tra_cost: 0.474741296873
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 86
# 	 iterations_done: 430
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 430:
# 	 tra_cost: 0.494594788399
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 87
# 	 iterations_done: 435
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 435:
# 	 tra_cost: 0.449153281134
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 88
# 	 iterations_done: 440
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 440:
# 	 tra_cost: 0.475818982247
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 89
# 	 iterations_done: 445
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 445:
# 	 tra_cost: 0.412549431328
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 90
# 	 iterations_done: 450
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 450:
# 	 tra_cost: 0.472396745255
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 91
# 	 iterations_done: 455
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 455:
# 	 tra_cost: 0.498810181702
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 92
# 	 iterations_done: 460
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 460:
# 	 tra_cost: 0.371169077974
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 93
# 	 iterations_done: 465
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 465:
# 	 tra_cost: 0.508129180396
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 94
# 	 iterations_done: 470
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 470:
# 	 tra_cost: 0.501780074826
# 	 tra_error: 0.181818181818
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 95
# 	 iterations_done: 475
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 475:
# 	 tra_cost: 0.419416377624
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 96
# 	 iterations_done: 480
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 480:
# 	 tra_cost: 0.474917402355
# ...
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 270
# 	 iterations_done: 1350
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1350:
# 	 tra_cost: 0.346263607131
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 271
# 	 iterations_done: 1355
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1355:
# 	 tra_cost: 0.327451866871
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 272
# 	 iterations_done: 1360
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1360:
# 	 tra_cost: 0.27564866447
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 273
# 	 iterations_done: 1365
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1365:
# 	 tra_cost: 0.299690082811
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 274
# 	 iterations_done: 1370
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1370:
# 	 tra_cost: 0.359497418863
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 275
# 	 iterations_done: 1375
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1375:
# 	 tra_cost: 0.307480101625
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 276
# 	 iterations_done: 1380
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1380:
# 	 tra_cost: 0.334070097801
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 277
# 	 iterations_done: 1385
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1385:
# 	 tra_cost: 0.267360979771
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 278
# 	 iterations_done: 1390
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1390:
# 	 tra_cost: 0.421884985178
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 279
# 	 iterations_done: 1395
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1395:
# 	 tra_cost: 0.358798999292
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 280
# 	 iterations_done: 1400
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1400:
# 	 tra_cost: 0.309322048019
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 281
# 	 iterations_done: 1405
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1405:
# 	 tra_cost: 0.335575979972
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 282
# 	 iterations_done: 1410
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1410:
# 	 tra_cost: 0.318463400782
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 283
# 	 iterations_done: 1415
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1415:
# 	 tra_cost: 0.335147049422
# 	 tra_error: 0.136363636364
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 284
# 	 iterations_done: 1420
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1420:
# 	 tra_cost: 0.363350811099
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 285
# 	 iterations_done: 1425
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1425:
# 	 tra_cost: 0.319287522506
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 286
# 	 iterations_done: 1430
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1430:
# 	 tra_cost: 0.32408184098
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 287
# 	 iterations_done: 1435
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1435:
# 	 tra_cost: 0.26141019507
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 288
# 	 iterations_done: 1440
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1440:
# 	 tra_cost: 0.293502663884
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 289
# 	 iterations_done: 1445
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1445:
# 	 tra_cost: 0.385670950711
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 290
# 	 iterations_done: 1450
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1450:
# 	 tra_cost: 0.284750086037
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 291
# 	 iterations_done: 1455
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1455:
# 	 tra_cost: 0.297505095799
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 292
# 	 iterations_done: 1460
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1460:
# 	 tra_cost: 0.371930159123
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 293
# 	 iterations_done: 1465
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1465:
# 	 tra_cost: 0.281573206487
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 294
# 	 iterations_done: 1470
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1470:
# 	 tra_cost: 0.264242098632
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 295
# 	 iterations_done: 1475
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1475:
# 	 tra_cost: 0.337065359166
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 296
# 	 iterations_done: 1480
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1480:
# 	 tra_cost: 0.325074198834
# 	 tra_error: 0.0909090909091
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 297
# 	 iterations_done: 1485
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1485:
# 	 tra_cost: 0.346332136866
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 298
# 	 iterations_done: 1490
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1490:
# 	 tra_cost: 0.327622504664
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 299
# 	 iterations_done: 1495
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1495:
# 	 tra_cost: 0.264127154788
# 	 tra_error: 0.0
#
#
# -------------------------------------------------------------------------------
# AFTER ANOTHER EPOCH
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 300
# 	 iterations_done: 1500
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1500:
# 	 tra_cost: 0.319790614324
# 	 tra_error: 0.0454545454545
#
#
# -------------------------------------------------------------------------------
# TRAINING HAS BEEN FINISHED:
# -------------------------------------------------------------------------------
# Training status:
# 	 batch_interrupt_received: False
# 	 epoch_interrupt_received: False
# 	 epoch_started: False
# 	 epochs_done: 300
# 	 iterations_done: 1500
# 	 received_first_batch: True
# 	 resumed_from: None
# 	 training_started: True
# Log records from the iteration 1500:
# 	 time_read_data_this_epoch: 0.000551462173462
# 	 time_read_data_total: 0.183265209198
# 	 time_train_this_epoch: 0.00091814994812
# 	 time_train_total: 0.306825399399
# 	 tra_cost: 0.319790614324
# 	 tra_error: 0.0454545454545
# 	 training_finish_requested: True
# 	 training_finished: True

# %%
loop.profile.report()
# Out:
# Section                                  Time     % of total
# ------------------------------------------------------------
# Before training                          0.00          0.00%
#   TrainingDataMonitoring                 0.00          0.00%
#   Printing                               0.00          0.00%
#   Timing                                 0.00          0.00%
#   FinishAfter                            0.00          0.00%
#   Other                                  0.00          0.00%
# Initialization                          12.57         91.62%
# Training                                 1.15          8.38%
#   Before epoch                           0.03          0.20%
#     TrainingDataMonitoring               0.01          0.04%
#     Printing                             0.01          0.08%
#     Timing                               0.00          0.03%
#     FinishAfter                          0.00          0.02%
#     Other                                0.00          0.03%
#   Epoch                                  0.97          7.05%
#     Read data                            0.18          1.34%
#     Before batch                         0.13          0.97%
#       TrainingDataMonitoring             0.03          0.19%
#       Printing                           0.05          0.37%
#       Timing                             0.02          0.16%
#       FinishAfter                        0.01          0.09%
#       Other                              0.02          0.17%
#     Train                                0.31          2.24%
#     After batch                          0.29          2.15%
#       TrainingDataMonitoring             0.18          1.31%
#       Printing                           0.05          0.38%
#       Timing                             0.02          0.16%
#       FinishAfter                        0.01          0.09%
#       Other                              0.03          0.21%
#     Other                                0.05          0.36%
#   After epoch                            0.14          1.01%
#     TrainingDataMonitoring               0.00          0.03%
#     Printing                             0.11          0.80%
#     Timing                               0.01          0.11%
#     FinishAfter                          0.00          0.03%
#     Other                                0.01          0.04%
#   Other                                  0.02          0.12%
# After training                           0.00          0.00%
#   TrainingDataMonitoring                 0.00          0.00%
#   Printing                               0.00          0.00%
#   Timing                                 0.00          0.00%
#   FinishAfter                            0.00          0.00%
#   Other                                  0.00          0.00%

# %%
predict = theano.function([x], y_hat)
x_vals, y_vals = stream.get_epoch_iterator().next()
y_pred = predict(x_vals)
metrics.accuracy_score(y_vals, y_pred > 0.5)
# Out:
# 0.9375

# %% [markdown]
# #Excercise:  Building more complex models
# Now, we are going to train a model with one more transformation (a MLP). Update the way to build the `y_hat` as follows:

# %%
linear_to_hidden = Linear(nfeatures, nhiddens,
                weights_init=Uniform(width=0.01), biases_init=Constant(0))

hidden_to_output = Linear(nhiddens, nclasses,
                weights_init=Constant(0), biases_init=Constant(0))

linear_to_hidden.initialize()
hidden_to_output.initialize()

h = Logistic().apply(linear_to_hidden.apply(x))
linear_output = hidden_to_output.apply(h)
softmax = Softmax()
y_hat = softmax.apply(linear_output)
learning_rate = 0.1

# %% [markdown]
# Re-run statements from [Cost](#cost)
# # Excercise: MLP with MNIST
# Modify the above code to train a MLP for MNIST dataset with Momentum update rule. Useful notes:
#  - You should use the `Flatten` transfomer to preprocess [MNIST](http://fuel.readthedocs.org/en/latest/api/dataset.html?#module-fuel.datasets.mnist) dataset
#  - Change the `Scale` update rule to the [Momentum](http://blocks.readthedocs.org/en/latest/api/algorithms.html?#blocks.algorithms.Momentum) rule and try values for `learning_rate` and `momentum` parameters
